# %% [markdown]
# # 01 — Exploración Inicial del Dataset
#
# **Objetivo:** Analizar y visualizar el dataset de imágenes recolectadas en la línea de pintura industrial antes de proceder con el entrenamiento.
#
# **Contenido:**
# 1. Carga y estadísticas del dataset
# 2. Visualización de imágenes de muestra
# 3. Análisis de distribución de clases
# 4. Análisis de tamaños de bounding boxes
# 5. Detección de imágenes problemáticas
# 6. Conclusiones y recomendaciones

# %%
# Imports
import os
import sys
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image

# Añadir raíz del proyecto al path
sys.path.insert(0, str(Path().resolve().parent))

# Configuración de plots
plt.rcParams['figure.figsize'] = (12, 6)
sns.set_theme(style='whitegrid')

# Rutas
DATA_DIR = Path('../data')
RAW_DIR = DATA_DIR / 'raw'
ANNOTATED_DIR = DATA_DIR / 'annotated'

print(f'Dataset dir: {ANNOTATED_DIR}')

# %% [markdown]
# ## 1. Estadísticas del Dataset

# %%
# TODO: Cargar rutas de imágenes y etiquetas
# TODO: Contar imágenes por split (train/val/test)
# TODO: Mostrar tabla resumen

# %% [markdown]
# ## 2. Visualización de Imágenes de Muestra

# %%
# TODO: Mostrar grid de imágenes aleatorias con sus bounding boxes dibujadas

# %% [markdown]
# ## 3. Distribución de Clases

# %%
# TODO: Parsear todos los archivos .txt de etiquetas
# TODO: Graficar histograma de instancias por clase

# %% [markdown]
# ## 4. Análisis de Tamaños de Bounding Boxes

# %%
# TODO: Graficar distribución de ancho y alto de bboxes normalizadas
# TODO: Scatter plot cx vs cy para detectar clustering espacial

# %% [markdown]
# ## 5. Detección de Imágenes Problemáticas

# %%
# TODO: Identificar imágenes sin etiqueta
# TODO: Identificar etiquetas sin imagen correspondiente
# TODO: Detectar imágenes corruptas

# %% [markdown]
# ## 6. Conclusiones
#
# *(Completar tras el análisis)*
#
# - **Balance de clases:** ...
# - **Tamaño típico de objetos:** ...
# - **Problemas detectados:** ...
# - **Recomendaciones:** ...
