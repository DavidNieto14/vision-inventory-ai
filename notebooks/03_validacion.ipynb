# %% [markdown]
# # 03 — Validación y Métricas del Modelo
#
# **Objetivo:** Evaluar el modelo entrenado sobre el conjunto de test y calcular métricas de rendimiento.
#
# **Contenido:**
# 1. Carga del modelo entrenado
# 2. Evaluación sobre test set (mAP, Precision, Recall)
# 3. Matriz de confusión
# 4. Análisis de casos de error (falsos positivos / negativos)
# 5. Validación de conteo vs. conteo manual
# 6. Conclusiones y métricas finales

# %%
# Imports
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import yaml
from ultralytics import YOLO

sys.path.insert(0, str(Path().resolve().parent))
from src.detector import PieceDetector
from src.counter import PieceCounter

plt.rcParams['figure.figsize'] = (12, 6)
sns.set_theme(style='whitegrid')

MODEL_PATH = '../models/best.pt'

# %% [markdown]
# ## 1. Carga del Modelo

# %%
# TODO: Cargar PieceDetector con el modelo entrenado
# detector = PieceDetector(model_path=MODEL_PATH)
# print(f'Modelo cargado: {MODEL_PATH}')
# print(f'Clases: {detector.model.names}')

# %% [markdown]
# ## 2. Evaluación Cuantitativa (mAP, Precision, Recall)

# %%
# TODO: Ejecutar model.val() sobre el test set
# TODO: Mostrar tabla de métricas por clase

# %% [markdown]
# ## 3. Matriz de Confusión

# %%
# TODO: Visualizar la matriz de confusión generada por Ultralytics

# %% [markdown]
# ## 4. Análisis de Errores

# %%
# TODO: Mostrar imágenes con falsos positivos
# TODO: Mostrar imágenes con falsos negativos
# TODO: Analizar patrones comunes de error

# %% [markdown]
# ## 5. Validación de Conteo vs. Conteo Manual

# %%
# TODO: Comparar conteos automáticos vs. ground truth manual
# TODO: Calcular % de discrepancia por clase
# TODO: Verificar si se cumple el objetivo de reducción ≥ 30%

# %% [markdown]
# ## 6. Conclusiones y Métricas Finales
#
# | Métrica          | Objetivo | Obtenido |
# |------------------|----------|----------|
# | mAP@50           | ≥ 0.85   | —        |
# | Reducción discrepancia | ≥ 30% | —   |
# | Latencia/frame   | < 100 ms | —        |
#
# *(Completar tras la evaluación)*
