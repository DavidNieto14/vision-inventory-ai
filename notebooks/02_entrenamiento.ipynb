# %% [markdown]
# # 02 — Pipeline de Entrenamiento YOLOv8
#
# **Objetivo:** Entrenar un modelo YOLOv8 personalizado para detección de piezas en la línea de pintura.
#
# **Contenido:**
# 1. Configuración del experimento
# 2. Preparación del dataset (data.yaml)
# 3. Augmentation sintética
# 4. Entrenamiento
# 5. Curvas de entrenamiento
# 6. Exportar pesos a `models/best.pt`

# %%
# Imports
import shutil
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import yaml
from ultralytics import YOLO

sys.path.insert(0, str(Path().resolve().parent))
from src.augmentation import SyntheticAugmentor

plt.rcParams['figure.figsize'] = (14, 5)

# %% [markdown]
# ## 1. Configuración del Experimento

# %%
# Cargar configuración del experimento
with open('../configs/experiment_config.yaml') as f:
    cfg = yaml.safe_load(f)

print(yaml.dump(cfg, default_flow_style=False))

# %% [markdown]
# ## 2. Preparación del Dataset (data.yaml)

# %%
# TODO: Generar data.yaml con rutas absolutas al dataset
# TODO: Verificar que todas las rutas existen antes de entrenar

# %% [markdown]
# ## 3. Augmentation Sintética

# %%
# TODO: Instanciar SyntheticAugmentor y generar imágenes adicionales
# augmentor = SyntheticAugmentor(seed=cfg['experiment']['seed'])
# total = augmentor.generate_dataset(
#     images_dir='../data/annotated/train/images',
#     labels_dir='../data/annotated/train/labels',
#     n_augmentations=cfg['augmentation']['n_augmentations']
# )
# print(f'Imágenes sintéticas generadas: {total}')

# %% [markdown]
# ## 4. Entrenamiento

# %%
# TODO: Lanzar entrenamiento YOLOv8
# model = YOLO(cfg['model']['pretrained_weights'])
# results = model.train(
#     data='data.yaml',
#     epochs=cfg['training']['epochs'],
#     imgsz=cfg['dataset']['image_size'],
#     batch=cfg['training']['batch_size'],
#     lr0=cfg['training']['learning_rate'],
#     patience=cfg['training']['patience'],
#     device=cfg['training']['device'],
#     project='../runs',
#     name=cfg['experiment']['name'],
#     seed=cfg['experiment']['seed'],
# )

# %% [markdown]
# ## 5. Curvas de Entrenamiento

# %%
# TODO: Leer results.csv de la carpeta de runs y graficar:
#   - Loss (box, cls, dfl) vs épocas
#   - mAP50 y mAP50-95 vs épocas

# %% [markdown]
# ## 6. Exportar Pesos

# %%
# TODO: Copiar best.pt a models/
# best_src = Path(f'../runs/{cfg["experiment"]["name"]}/weights/best.pt')
# best_dst = Path('../models/best.pt')
# shutil.copy(best_src, best_dst)
# print(f'Pesos exportados a {best_dst}')
